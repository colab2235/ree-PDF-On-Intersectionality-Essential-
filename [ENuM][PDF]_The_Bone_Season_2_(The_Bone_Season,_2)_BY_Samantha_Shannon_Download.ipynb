# %% [markdown]
# <a href="https://colab.research.google.com/github/colab2235/ree-PDF-On-Intersectionality-Essential-/blob/main/%5BENuM%5D%5BPDF%5D_The_Bone_Season_2_(The_Bone_Season%2C_2)_BY_Samantha_Shannon_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Bone Season (The Bone Season, #1)
#
# READ &** DOWNLOAD Samantha Shannon book** **The Bone Season (The Bone Season, #1) **in PDF, EPub, Mobi, Kindle online. Free book, AudioBook, Reender Book The Bone Season (The Bone Season, #1) by Samantha Shannon full book,full ebook full Download.
#
# **[Download](https://www.ebookmaya.com/)**
# ![A_Business_Proposal.jpg](data:image/jpeg;base64,...)

# %%
# %%html
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-S92BYF3H7Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-S92BYF3H7Q');
# </script>
# Out:
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-S92BYF3H7Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-S92BYF3H7Q');
# </script>

# %% [markdown]
# ```
# # This is formatted as code
# ```
# <meta name="google-site-verification" W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc />

# %%
<meta name="google-site-verification" content="W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc" />

# %%
<meta name="google-site-verification" "W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc" />
# Out:
#   File "<ipython-input-7-cdbe6f50dbe1>", line 1
#     <meta name="google-site-verification" "W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc" />
#     ^
# SyntaxError: invalid syntax

# %%
verification_value = 'W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc'

head = soup.find('head')
meta_tag = soup.new_tag('meta', name='google-site-verification', content=verification_value)
head.append(meta_tag)

print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dbf47802c89e> in <cell line: 3>()
#       1 verification_value = 'W3hhLfc31Z1VWeFajxUxb3pFrTYPNjnV4TDz_-zNNMc'
#       2
# ----> 3 head = soup.find('head')
#       4 meta_tag = soup.new_tag('meta', name='google-site-verification', content=verification_value)
#       5 head.append(meta_tag)
#
# NameError: name 'soup' is not defined

# %% [markdown]
# %%html
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-S92BYF3H7Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-S92BYF3H7Q');
# </script>

# %% [markdown]
# ```
# %%html
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-S92BYF3H7Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-S92BYF3H7Q');
# </script>
#
# ```
# %%html
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-S92BYF3H7Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-S92BYF3H7Q');
# </script>
